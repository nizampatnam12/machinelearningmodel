# %% [markdown]
# <a href="https://colab.research.google.com/github/nizampatnam12/machinelearningmodel/blob/main/machinelearningmodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)

ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)
print(model.predict(x=np.array([10.0])))
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 4.6676
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 3.8441
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 3.1926
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 2.6767
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 2.2674
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 1.9420
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1.6828
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.4757
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1.3096
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.1759
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.0677
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.9797
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.9075
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.8480
# Epoch 15/500
# ...
